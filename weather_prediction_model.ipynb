# %%
import pandas as pd

# %%
df = pd.read_csv('Karachi weather.csv')

# %%
df
# Out:
#          STATION                      NAME        DATE  PRCP  TAVG  TMAX  TMIN
# 0    PKM00041780  JINNAH INTERNATIONAL, PK  2023-01-01   0.0    67  83.0  52.0
# 1    PKM00041780  JINNAH INTERNATIONAL, PK  2023-01-02   0.0    66  81.0  53.0
# 2    PKM00041780  JINNAH INTERNATIONAL, PK  2023-01-03   0.0    66  78.0  52.0
# 3    PKM00041780  JINNAH INTERNATIONAL, PK  2023-01-04   0.0    64  77.0  53.0
# 4    PKM00041780  JINNAH INTERNATIONAL, PK  2023-01-05   0.0    64  76.0  51.0
# ..           ...                       ...         ...   ...   ...   ...   ...
# 152  PKM00041780  JINNAH INTERNATIONAL, PK  2023-06-02   0.0    89  96.0  84.0
# 153  PKM00041780  JINNAH INTERNATIONAL, PK  2023-06-03   0.0    90  98.0  84.0
# 154  PKM00041780  JINNAH INTERNATIONAL, PK  2023-06-04   0.0    89  96.0  84.0
# 155  PKM00041780  JINNAH INTERNATIONAL, PK  2023-06-05   0.0    89  96.0  83.0
# 156  PKM00041780  JINNAH INTERNATIONAL, PK  2023-06-06   0.0    90  96.0  85.0
#
# [157 rows x 7 columns]

# %%
df = pd.read_csv('Karachi weather.csv', index_col = "DATE")
df
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN
# DATE
# 2023-01-01  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    67  83.0  52.0
# 2023-01-02  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    66  81.0  53.0
# 2023-01-03  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    66  78.0  52.0
# 2023-01-04  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    64  77.0  53.0
# 2023-01-05  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    64  76.0  51.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2023-06-02  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    89  96.0  84.0
# 2023-06-03  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    90  98.0  84.0
# 2023-06-04  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    89  96.0  84.0
# 2023-06-05  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    89  96.0  83.0
# 2023-06-06  PKM00041780  JINNAH INTERNATIONAL, PK   0.0    90  96.0  85.0
#
# [157 rows x 6 columns]

# %%
n = df.apply(pd.isnull)
n
# Out:
#             STATION   NAME   PRCP   TAVG   TMAX   TMIN
# DATE
# 2023-01-01    False  False  False  False  False  False
# 2023-01-02    False  False  False  False  False  False
# 2023-01-03    False  False  False  False  False  False
# 2023-01-04    False  False  False  False  False  False
# 2023-01-05    False  False  False  False  False  False
# ...             ...    ...    ...    ...    ...    ...
# 2023-06-02    False  False  False  False  False  False
# 2023-06-03    False  False  False  False  False  False
# 2023-06-04    False  False  False  False  False  False
# 2023-06-05    False  False  False  False  False  False
# 2023-06-06    False  False  False  False  False  False
#
# [157 rows x 6 columns]

# %%
# s = df.apply(pd.isnull).sum()
# s
n.sum()
# Out:
# STATION     0
# NAME        0
# PRCP        4
# TAVG        0
# TMAX        1
# TMIN       23
# dtype: int64

# %%
x = df.apply(pd.isnull).sum()/df.shape[0]     # "df.shape[0]" divides the sum of missing values in each column by the total number of rows in the DataFrame. This calculates the proportion of missing values in each column.
x
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.025478
# TAVG       0.000000
# TMAX       0.006369
# TMIN       0.146497
# dtype: float64

# %%
df1 = df.drop(columns = ["STATION", "NAME"])
df1
# Out:
#             PRCP  TAVG  TMAX  TMIN
# DATE
# 2023-01-01   0.0    67  83.0  52.0
# 2023-01-02   0.0    66  81.0  53.0
# 2023-01-03   0.0    66  78.0  52.0
# 2023-01-04   0.0    64  77.0  53.0
# 2023-01-05   0.0    64  76.0  51.0
# ...          ...   ...   ...   ...
# 2023-06-02   0.0    89  96.0  84.0
# 2023-06-03   0.0    90  98.0  84.0
# 2023-06-04   0.0    89  96.0  84.0
# 2023-06-05   0.0    89  96.0  83.0
# 2023-06-06   0.0    90  96.0  85.0
#
# [157 rows x 4 columns]

# %%
df1["PRCP"].value_counts()
# Out:
# 0.00    146
# 0.01      3
# 0.17      1
# 0.04      1
# 0.09      1
# 0.57      1
# Name: PRCP, dtype: int64

# %%
df1["PRCP"] = df1["PRCP"].fillna(0)

# %%
df1["TMIN"].value_counts()
# Out:
# 84.0    9
# 79.0    9
# 78.0    7
# 83.0    7
# 73.0    6
# 74.0    5
# 68.0    5
# 57.0    5
# 82.0    5
# 72.0    5
# 69.0    5
# 52.0    4
# 49.0    4
# 56.0    4
# 54.0    4
# 71.0    3
# 77.0    3
# 65.0    3
# 75.0    3
# 66.0    3
# 63.0    3
# 53.0    3
# 51.0    3
# 70.0    3
# 48.0    3
# 64.0    2
# 81.0    2
# 47.0    2
# 85.0    2
# 59.0    2
# 76.0    2
# 60.0    1
# 45.0    1
# 55.0    1
# 80.0    1
# 58.0    1
# 43.0    1
# 67.0    1
# 46.0    1
# Name: TMIN, dtype: int64

# %%
df1[pd.isnull(df1["TMIN"])]
# Out:
#             PRCP  TAVG  TMAX  TMIN
# DATE
# 2023-01-12  0.00    67  76.0   NaN
# 2023-01-14  0.00    61  74.0   NaN
# 2023-01-16  0.00    63  77.0   NaN
# 2023-01-20  0.00    64  77.0   NaN
# 2023-01-21  0.00    65  76.0   NaN
# 2023-01-22  0.00    63  74.0   NaN
# 2023-02-09  0.00    76  84.0   NaN
# 2023-02-11  0.00    76  90.0   NaN
# 2023-02-12  0.00    74  87.0   NaN
# 2023-02-20  0.00    77  88.0   NaN
# 2023-02-24  0.00    76  87.0   NaN
# 2023-03-03  0.00    84  94.0   NaN
# 2023-03-05  0.00    84  97.0   NaN
# 2023-03-20  0.00    78  88.0   NaN
# 2023-03-30  0.04    81  88.0   NaN
# 2023-03-31  0.00    81  88.0   NaN
# 2023-04-08  0.00    85  99.0   NaN
# 2023-04-15  0.00    85  93.0   NaN
# 2023-04-26  0.00    86  96.0   NaN
# 2023-04-28  0.00    83  91.0   NaN
# 2023-04-29  0.00    81  91.0   NaN
# 2023-05-19  0.00    89  98.0   NaN
# 2023-05-28  0.00    89  96.0   NaN

# %%
df1 = df1.interpolate()

# %%
df1.apply(pd.isnull).sum()/df1.shape[0]
# Out:
# PRCP    0.0
# TAVG    0.0
# TMAX    0.0
# TMIN    0.0
# dtype: float64

# %%
df1.dtypes
# Out:
# PRCP    float64
# TAVG      int64
# TMAX    float64
# TMIN    float64
# dtype: object

# %%
df1.index
# Out:
# Index(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#        '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10',
#        ...
#        '2023-05-28', '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#        '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05', '2023-06-06'],
#       dtype='object', name='DATE', length=157)

# %%
df1.index = pd.to_datetime(df1.index)

# %%
df1.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-05-28', '2023-05-29', '2023-05-30', '2023-05-31',
#                '2023-06-01', '2023-06-02', '2023-06-03', '2023-06-04',
#                '2023-06-05', '2023-06-06'],
#               dtype='datetime64[ns]', name='DATE', length=157, freq=None)

# %%
df1.apply(lambda x: (x==9999).sum())
# Out:
# PRCP    0
# TAVG    0
# TMAX    0
# TMIN    0
# dtype: int64

# %%
df1[["TMAX", "TMIN"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df1[["PRCP"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Creating Model

# %%
df1["TARGET"] = df1.shift(-1)["TMAX"]   #predicting tomorrows data from today

# %%
df1
# Out:
#             PRCP  TAVG  TMAX  TMIN  TARGET
# DATE
# 2023-01-01   0.0    67  83.0  52.0    81.0
# 2023-01-02   0.0    66  81.0  53.0    78.0
# 2023-01-03   0.0    66  78.0  52.0    77.0
# 2023-01-04   0.0    64  77.0  53.0    76.0
# 2023-01-05   0.0    64  76.0  51.0    78.0
# ...          ...   ...   ...   ...     ...
# 2023-06-02   0.0    89  96.0  84.0    98.0
# 2023-06-03   0.0    90  98.0  84.0    96.0
# 2023-06-04   0.0    89  96.0  84.0    96.0
# 2023-06-05   0.0    89  96.0  83.0    96.0
# 2023-06-06   0.0    90  96.0  85.0     NaN
#
# [157 rows x 5 columns]

# %%
df1 = df1.iloc[:-1,:].copy()

# %%
df1
# Out:
#             PRCP  TAVG  TMAX  TMIN  TARGET
# DATE
# 2023-01-01   0.0    67  83.0  52.0    81.0
# 2023-01-02   0.0    66  81.0  53.0    78.0
# 2023-01-03   0.0    66  78.0  52.0    77.0
# 2023-01-04   0.0    64  77.0  53.0    76.0
# 2023-01-05   0.0    64  76.0  51.0    78.0
# ...          ...   ...   ...   ...     ...
# 2023-06-01   0.0    88  95.0  84.0    96.0
# 2023-06-02   0.0    89  96.0  84.0    98.0
# 2023-06-03   0.0    90  98.0  84.0    96.0
# 2023-06-04   0.0    89  96.0  84.0    96.0
# 2023-06-05   0.0    89  96.0  83.0    96.0
#
# [156 rows x 5 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ['PRCP','TMAX','TMIN']

# %%
train = df1.loc[:"2023-05-15"]
test = df1.loc["2023-05-16":]

# %%
test
# Out:
#             PRCP  TAVG  TMAX  TMIN  TARGET
# DATE
# 2023-05-16   0.0    88  95.0  83.0    95.0
# 2023-05-17   0.0    88  95.0  83.0    95.0
# 2023-05-18   0.0    89  95.0  82.0    98.0
# 2023-05-19   0.0    89  98.0  82.0    95.0
# 2023-05-20   0.0    88  95.0  82.0    95.0
# 2023-05-21   0.0    88  95.0  82.0    94.0
# 2023-05-22   0.0    88  94.0  83.0    95.0
# 2023-05-23   0.0    88  95.0  84.0    95.0
# 2023-05-24   0.0    88  95.0  83.0    95.0
# 2023-05-25   0.0    89  95.0  84.0    96.0
# 2023-05-26   0.0    88  96.0  85.0    95.0
# 2023-05-27   0.0    89  95.0  84.0    96.0
# 2023-05-28   0.0    89  96.0  84.0    96.0
# 2023-05-29   0.0    89  96.0  84.0    95.0
# 2023-05-30   0.0    89  95.0  84.0    94.0
# 2023-05-31   0.0    88  94.0  82.0    95.0
# 2023-06-01   0.0    88  95.0  84.0    96.0
# 2023-06-02   0.0    89  96.0  84.0    98.0
# 2023-06-03   0.0    90  98.0  84.0    96.0
# 2023-06-04   0.0    89  96.0  84.0    96.0
# 2023-06-05   0.0    89  96.0  83.0    96.0

# %%
reg.fit(train[predictors], train["TARGET"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["TARGET"], predictions)
# Out:
# 1.776349540624108

# %%
combined = pd.concat([test["TARGET"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["ACTUAL", "PREDICTED"]

# %%
combined
# Out:
#             ACTUAL  PREDICTED
# DATE
# 2023-05-16    95.0  95.739701
# 2023-05-17    95.0  95.739701
# 2023-05-18    98.0  95.628250
# 2023-05-19    95.0  98.006388
# 2023-05-20    95.0  95.628250
# 2023-05-21    94.0  95.628250
# 2023-05-22    95.0  94.946988
# 2023-05-23    95.0  95.851152
# 2023-05-24    95.0  95.739701
# 2023-05-25    96.0  95.851152
# 2023-05-26    95.0  96.755316
# 2023-05-27    96.0  95.851152
# 2023-05-28    96.0  96.643865
# 2023-05-29    95.0  96.643865
# 2023-05-30    94.0  95.851152
# 2023-05-31    95.0  94.835537
# 2023-06-01    96.0  95.851152
# 2023-06-02    98.0  96.643865
# 2023-06-03    96.0  98.229291
# 2023-06-04    96.0  96.643865
# 2023-06-05    96.0  96.532414

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([3.95128405, 0.79271282, 0.1114513 ])

# %%
def make_predictions(predictors, df1, reg):
    train = df1.loc[:"2023-05-15"]
    test = df1.loc["2023-05-16":]
    reg.fit(train[predictors], train["TARGET"])
    predictions = reg.predict(test[predictors])
    error = mean_squared_error(test["TARGET"], predictions)
    combined = pd.concat([test["TARGET"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["ACTUAL", "PREDICTED"]
    return error, combined

# %% [markdown]
# Adding more predictors

# %%
df1["MONTH_MAX"] = df1["TMAX"].rolling(30).mean()

# df1["month_day_max"] = df1["month_max"] / df1["temp_max"]

# df1["max_min"] = df1["temp_max"] / df1["temp_min"]

# %%
df1
# Out:
#             PRCP  TAVG  TMAX  TMIN  TARGET  MONTH_MAX
# DATE
# 2023-01-01   0.0    67  83.0  52.0    81.0        NaN
# 2023-01-02   0.0    66  81.0  53.0    78.0        NaN
# 2023-01-03   0.0    66  78.0  52.0    77.0        NaN
# 2023-01-04   0.0    64  77.0  53.0    76.0        NaN
# 2023-01-05   0.0    64  76.0  51.0    78.0        NaN
# ...          ...   ...   ...   ...     ...        ...
# 2023-06-01   0.0    88  95.0  84.0    96.0  96.166667
# 2023-06-02   0.0    89  96.0  84.0    98.0  96.233333
# 2023-06-03   0.0    90  98.0  84.0    96.0  96.366667
# 2023-06-04   0.0    89  96.0  84.0    96.0  96.433333
# 2023-06-05   0.0    89  96.0  83.0    96.0  96.433333
#
# [156 rows x 6 columns]

# %% [markdown]
# We need before 30 days to predict MONTH_MAX therefore getting NaN values on starting dates

# %%
df1["MONTH_DAY_MAX"] = df1["MONTH_MAX"] / df1["TMAX"]

df1["MAX_MIN RATIO"] = df1["TMAX"] / df1["TMIN"]

# %%
df1
# Out:
#             PRCP  TAVG  TMAX  TMIN  TARGET  MONTH_MAX  MONTH_DAY_MAX  \
# DATE
# 2023-01-01   0.0    67  83.0  52.0    81.0        NaN            NaN
# 2023-01-02   0.0    66  81.0  53.0    78.0        NaN            NaN
# 2023-01-03   0.0    66  78.0  52.0    77.0        NaN            NaN
# 2023-01-04   0.0    64  77.0  53.0    76.0        NaN            NaN
# 2023-01-05   0.0    64  76.0  51.0    78.0        NaN            NaN
# ...          ...   ...   ...   ...     ...        ...            ...
# 2023-06-01   0.0    88  95.0  84.0    96.0  96.166667       1.012281
# 2023-06-02   0.0    89  96.0  84.0    98.0  96.233333       1.002431
# 2023-06-03   0.0    90  98.0  84.0    96.0  96.366667       0.983333
# 2023-06-04   0.0    89  96.0  84.0    96.0  96.433333       1.004514
# 2023-06-05   0.0    89  96.0  83.0    96.0  96.433333       1.004514
#
#             MAX_MIN RATIO
# DATE
# 2023-01-01       1.596154
# 2023-01-02       1.528302
# 2023-01-03       1.500000
# ...

# %%
predictors = ["PRCP", "TMAX", "TMIN", "MONTH_DAY_MAX", "MAX_MIN RATIO"]

error, combined = make_predictions(predictors, df1, reg)
error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\FIVEST~1\AppData\Local\Temp/ipykernel_8560/382444563.py in <module>
#       1 predictors = ["PRCP", "TMAX", "TMIN", "MONTH_DAY_MAX", "MAX_MIN RATIO"]
#       2
# ----> 3 error, combined = make_predictions(predictors, df1, reg)
#       4 error
#
# C:\Users\FIVEST~1\AppData\Local\Temp/ipykernel_8560/1617538786.py in make_predictions(predictors, df1, reg)
#       2     train = df1.loc[:"2023-05-15"]
#       3     test = df1.loc["2023-05-16":]
# ----> 4     reg.fit(train[predictors], train["TARGET"])
#       5     predictions = reg.predict(test[predictors])
#       6     error = mean_squared_error(test["TARGET"], predictions)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#    1124
# ...

# %%
df1 = df1.iloc[30:,:].copy()

# %%
predictors = ["PRCP", "TMAX", "TMIN", "MONTH_DAY_MAX", "MAX_MIN RATIO"]

error, combined = make_predictions(predictors, df1, reg)
error
# Out:
# 1.306312380326398

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([ 3.29069306,  0.69610495,  0.08067088, -0.69163283, -0.56989777])

# %%
df1.corr()["TARGET"]
# Out:
# PRCP             0.000996
# TAVG             0.755214
# TMAX             0.819459
# TMIN             0.618593
# TARGET           1.000000
# MONTH_MAX        0.617745
# MONTH_DAY_MAX   -0.079181
# MAX_MIN RATIO   -0.372686
# Name: TARGET, dtype: float64

# %%
combined["DIFFERENCE"] = (combined["ACTUAL"] - combined["PREDICTED"]).abs()
combined.sort_values("DIFFERENCE", ascending=False).head(10)
# Out:
#             ACTUAL  PREDICTED  DIFFERENCE
# DATE
# 2023-05-18    98.0  95.288404    2.711596
# 2023-05-19    95.0  97.376771    2.376771
# 2023-06-02    98.0  96.159658    1.840342
# 2023-06-03    96.0  97.551507    1.551507
# 2023-05-30    94.0  95.464253    1.464253
# 2023-05-21    94.0  95.288404    1.288404
# 2023-05-26    95.0  96.253755    1.253755
# 2023-05-29    95.0  96.162539    1.162539
# 2023-06-01    96.0  95.463525    0.536475
# 2023-05-27    96.0  95.468378    0.531622
